# %% [markdown]
# # Analisa Data Pokemon

# %%
import pandas as pd

# %%
'data_pokemon.csv'
# Out:
# 'data_pokemon.csv'

# %% [markdown]
# #### Membuka DataFrame

# %%
data_pokemon = pd.read_csv('data_pokemon.csv')

# %% [markdown]
# #### Melihat 5 data pertama dan 5 data terakhir dari dataframe

# %%
data_pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison  318.0  45      49       49       65     65.0
# 1  2     Ivysaur  Grass  Poison  405.0  60      62       63       80     80.0
# 2  3    Venusaur  Grass  Poison  525.0  80      82       83      100    100.0
# 3  4  Charmander   Fire     NaN  309.0  39      52       43       60     50.0
# 4  5  Charmeleon   Fire     NaN  405.0  58      64       58       80     65.0
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %% [markdown]
# ###### Jenis Missing Value -> NaN, None, ''" (empty string)

# %%
data_pokemon.tail()
# Out:
#        #       Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 146  147    Dratini   Dragon     NaN  300.0   41      64       45       50
# 147  148  Dragonair   Dragon     NaN  420.0   61      84       65       70
# 148  149  Dragonite   Dragon  Flying    NaN   91     134       95      100
# 149  150     Mewtwo  Psychic     NaN  680.0  106     110       90      154
# 150  151        Mew  Psychic     NaN    NaN  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 146     50.0     50      1      False
# 147     70.0     70      2      False
# 148    100.0     80      3      False
# 149     90.0    130      1       True
# 150    100.0    100      1      False

# %% [markdown]
# #### Cek details dari dataframe

# %%
data_pokemon.shape
# Out:
# (151, 13)

# %%
len(data_pokemon)
# Out:
# 151

# %%
data_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      146 non-null    float64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    143 non-null    float64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), float64(2), int64(7), object(3)
# memory usage: 14.4+ KB

# %% [markdown]
# #### Rename Columns 1

# %%
data_pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
data_pokemon.columns = ['No', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary']

# %%
data_pokemon.head()
# Out:
#    No        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison  318.0  45      49       49       65
# 1   2     Ivysaur  Grass  Poison  405.0  60      62       63       80
# 2   3    Venusaur  Grass  Poison  525.0  80      82       83      100
# 3   4  Charmander   Fire     NaN  309.0  39      52       43       60
# 4   5  Charmeleon   Fire     NaN  405.0  58      64       58       80
#
#    Sp. Def  Speed  Stage  Legendary
# 0     65.0     45      1      False
# 1     80.0     60      2      False
# 2    100.0     80      3      False
# 3     50.0     65      1      False
# 4     65.0     80      2      False

# %% [markdown]
# #### Karena kolumn 'Type 2' diatas tampak anomali (cuman ada 67 non-null, cek column itu)

# %%
data_pokemon[['Type 2']]
# Out:
#      Type 2
# 0    Poison
# 1    Poison
# 2    Poison
# 3       NaN
# 4       NaN
# ..      ...
# 146     NaN
# 147     NaN
# 148  Flying
# 149     NaN
# 150     NaN
#
# [151 rows x 1 columns]

# %%
type(data_pokemon[['Type 2']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_pokemon['Type 2']) # Series = Seperti List, tapi spesifik untuk value dari sebuah column dari sebuah dataframe
# Out:
# pandas.core.series.Series

# %%
data_pokemon[['Type 2']].to_excel('data_pokemon_type_2.xlsx')

# %%
data_pokemon['Type 2'].to_excel('data_pokemon_type_2_series.xlsx')

# %% [markdown]
# #### Ternyata, index nomor 3 dan 4, value Type 2 nya kosong. cek baris itu

# %%
data_pokemon[3:5]
# Out:
#    No        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 3   4  Charmander   Fire    NaN  309.0  39      52       43       60     50.0
# 4   5  Charmeleon   Fire    NaN  405.0  58      64       58       80     65.0
#
#    Speed  Stage  Legendary
# 3     65      1      False
# 4     80      2      False

# %% [markdown]
# #### Karena Column Sp. Def & Total juga ada yang null, ayo diisi

# %%
# untuk Sp. Def -> Mean
values = data_pokemon['Sp. Def'].mean() # slicing dari dataframe data_pokemon column Sp. Def, cari rata2 valuenya.
data_pokemon['Sp. Def'] = data_pokemon['Sp. Def'].fillna(values) # Isi NaN value menggunakan Values diatas.

# %%
data_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      146 non-null    float64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    float64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), float64(2), int64(7), object(3)
# memory usage: 14.4+ KB

# %%
data_pokemon['Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 151 entries, 0 to 150
# Series name: Total
# Non-Null Count  Dtype
# --------------  -----
# 146 non-null    float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
sum_total = data_pokemon['Total'].sum()
length_of_not_null_total = 146

# %%
mean_with_151_values = sum_total/151
mean_with_145_values = sum_total/146

mean_dari_pandas_mean = data_pokemon['Total'].mean()

# %%
print(mean_with_151_values)
# Out:
# 390.3907284768212

# %%
mean_with_145_values
# Out:
# 403.76027397260276

# %%
mean_dari_pandas_mean
# Out:
# 403.76027397260276

# %%
# untuk Total -> Median
med = data_pokemon['Total'].median()
data_pokemon['Total'] = data_pokemon['Total'].fillna(med)

# %%
data_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    float64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    float64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), float64(2), int64(7), object(3)
# memory usage: 14.4+ KB

# %% [markdown]
# #### Check Status missing value lagi

# %%
data_pokemon.isnull().sum()
# Out:
# No            0
# Name          0
# Type 1        0
# Type 2       84
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Stage         0
# Legendary     0
# dtype: int64

# %% [markdown]
# #### Ternyata ada 84 missing value di Type 2. Datanya cuman ada 151, 50% dari data missing. Handlingnya?

# %%
data_pokemon=data_pokemon.drop(columns=['Type 2'])

# %% [markdown]
# #### Final Check

# %%
data_pokemon
# Out:
#       No        Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  318.0   45      49       49       65     65.0
# 1      2     Ivysaur    Grass  405.0   60      62       63       80     80.0
# 2      3    Venusaur    Grass  525.0   80      82       83      100    100.0
# 3      4  Charmander     Fire  309.0   39      52       43       60     50.0
# 4      5  Charmeleon     Fire  405.0   58      64       58       80     65.0
# ..   ...         ...      ...    ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon  300.0   41      64       45       50     50.0
# 147  148   Dragonair   Dragon  420.0   61      84       65       70     70.0
# 148  149   Dragonite   Dragon  405.0   91     134       95      100    100.0
# 149  150      Mewtwo  Psychic  680.0  106     110       90      154     90.0
# 150  151         Mew  Psychic  405.0  100     100      100      100    100.0
#
#      Speed  Stage  Legendary
# ...

# %%
data_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Total      151 non-null    float64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    float64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), float64(2), int64(7), object(2)
# memory usage: 13.2+ KB

# %% [markdown]
# #### Sudah tidak ada kolumn yang ada missing value, mulai analisa

# %%
data_pokemon.head()
# Out:
#    No        Name Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0   1   Bulbasaur  Grass  318.0  45      49       49       65     65.0     45
# 1   2     Ivysaur  Grass  405.0  60      62       63       80     80.0     60
# 2   3    Venusaur  Grass  525.0  80      82       83      100    100.0     80
# 3   4  Charmander   Fire  309.0  39      52       43       60     50.0     65
# 4   5  Charmeleon   Fire  405.0  58      64       58       80     65.0     80
#
#    Stage  Legendary
# 0      1      False
# 1      2      False
# 2      3      False
# 3      1      False
# 4      2      False

# %% [markdown]
# #### Berapa jumlah pokemon yang terdapat di data?,  dan apa saja?

# %%
data_pokemon['Name'].nunique()
# Out:
# 150

# %%
data_pokemon.nunique()
# Out:
# No           151
# Name         150
# Type 1        15
# Total         73
# HP            42
# Attack        46
# Defense       44
# Sp. Atk       34
# Sp. Def       30
# Speed         42
# Stage          3
# Legendary      2
# dtype: int64

# %%
data_pokemon['Name'].unique()
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#        'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#        'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill', 'Pidgey',
#        'Pidgeotto', 'Pidgeot', 'Rattata', 'Raticate', 'Spearow', 'Fearow',
#        'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash',
#        'Nidoran���', 'Nidorina', 'Nidoqueen', 'Nidorino', 'Nidoking',
#        'Clefairy', 'Clefable', 'Vulpix', 'Ninetales', 'Jigglypuff',
#        'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume',
#        'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett', 'Dugtrio',
#        'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey', 'Primeape',
#        'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl', 'Poliwrath',
#        'Abra', 'Kadabra', 'Alakazam', 'Machop', 'Machoke', 'Machamp',
#        'Bellsprout', 'Weepinbell', 'Victreebel', 'Tentacool',
# ...

# %% [markdown]
# #### Pokemon apa yang mempunyai Attack paling tinggi?

# %%
data_pokemon.loc[data_pokemon['Attack'] == data_pokemon['Attack'].max()]
# Out:
#       No       Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 148  149  Dragonite  Dragon  405.0  91     134       95      100    100.0
#
#      Speed  Stage  Legendary
# 148     80      3      False

# %% [markdown]
# #### Pokemon tipe apa yang mempunyai highest speed?

# %%
data_pokemon.loc[data_pokemon['Speed']==data_pokemon['Speed'].max()]['Type 1']
# cari di df, data yang mempunyai 'Speed' dengan nilai yang sama dengan maximum Speed. 
# Lalu slicing agar hanya mendapat 'Type 1'-nya
# Out:
# 100    Electric
# Name: Type 1, dtype: object

# %% [markdown]
# #### Pokemon tipe 1 Dragon punya rata-rata defense berapa?

# %%
data_pokemon.loc[data_pokemon['Type 1'].isin(['Dragon'])].groupby(by='Type 1').mean()['Defense']
# cari di df, data yang mempunyai 'Type 1' dengan nilai yang sama dengan 'Dragon'. Lalu slicing agar hanya mendapat 'Defense'-nya. Nah, defensenya di cari rata2nya.
# Out:
# Type 1
# Dragon    68.333333
# Name: Defense, dtype: float64

# %%
data_pokemon.loc[data_pokemon['Type 1'] == 'Dragon']['Defense'].mean()
# Out:
# 68.33333333333333

# %% [markdown]
# #### Dari tipe Water or Fire Pokemon, mana yang lebih tinggi rata2 attack speednya?

# %%
data_pokemon.loc[data_pokemon['Type 1'].isin(['Water','Fire'])]
# cari di df, data yang mempunyai 'Type 1' dengan nilai yang ada di dalam ['Water', 'Fire']. 
# lalu group-in, dan untuk masing2 group, cari rata2nya.
# lalu di slice hanya menampilkan rata2 Sp. Atk
# Out:
# Type 1
# Fire     84.583333
# Water    64.821429
# Name: Sp. Atk, dtype: float64

# %%
data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').mean()['Sp. Atk']
# data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').median()
# data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').max()
# data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').min()
# data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').std()
# data_pokemon.loc[data_pokemon['Type 1'].isin(['Water', 'Fire'])].groupby(by='Type 1').var()
# Out:
# Type 1
# Fire     84.583333
# Water    64.821429
# Name: Sp. Atk, dtype: float64

# %% [markdown]
# #### Type Pokemon apa yang lebih banyak terklasifikasi kedalam 'Legendary'?

# %%
data_pokemon.loc[data_pokemon['Legendary'] == True].groupby(by='Type 1').nunique()['Name']
# cari di df, data yang mempunyai 'Legendary' dengan nilai sama dengan True. 
# lalu group-in, dan untuk masing2 group, cari ada berapa jumlah unique name disana.
# lalu di slice hanya menampilkan jumlah unique nama.
# Out:
# Type 1
# Electric    1
# Fire        1
# Ice         1
# Psychic     1
# Name: Name, dtype: int64

# %% [markdown]
# ### Multiple Filtering

# %%
data_pokemon_legendary = data_pokemon.loc[data_pokemon['Legendary'] == True]

# %%
data_pokemon.loc[data_pokemon['Stage'] == 2]
# Out:
#       No        Name    Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 1      2     Ivysaur     Grass  405.0   60      62       63       80
# 4      5  Charmeleon      Fire  405.0   58      64       58       80
# 7      8   Wartortle     Water  405.0   59      63       80       65
# 10    11     Metapod       Bug  205.0   50      20       55       25
# 13    14      Kakuna       Bug  205.0   45      25       50       25
# 16    17   Pidgeotto    Normal  349.0   63      60       55       50
# 19    20    Raticate    Normal  413.0   55      81       60       50
# 21    22      Fearow    Normal  442.0   65      90       65       61
# 23    24       Arbok    Poison  438.0   60      85       69       65
# 25    26      Raichu  Electric  485.0   60      90       55       90
# 27    28   Sandslash    Ground  450.0   75     100      110       45
# 29    30    Nidorina    Poison  365.0   70      62       67       55
# 32    33    Nidorino    Poison  365.0   61      72       57       55
# ...

# %%
print(data_pokemon_legendary.shape)
print(data_pokemon_legendary_stage_2.shape)
# Out:
# (4, 12)
# (0, 12)

# %% [markdown]
# #### Membuat Column Baru dari sebuah operasi

# %%
data_pokemon
# Out:
#       No        Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  318.0   45      49       49       65     65.0
# 1      2     Ivysaur    Grass  405.0   60      62       63       80     80.0
# 2      3    Venusaur    Grass  525.0   80      82       83      100    100.0
# 3      4  Charmander     Fire  309.0   39      52       43       60     50.0
# 4      5  Charmeleon     Fire  405.0   58      64       58       80     65.0
# ..   ...         ...      ...    ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon  300.0   41      64       45       50     50.0
# 147  148   Dragonair   Dragon  420.0   61      84       65       70     70.0
# 148  149   Dragonite   Dragon  405.0   91     134       95      100    100.0
# 149  150      Mewtwo  Psychic  680.0  106     110       90      154     90.0
# 150  151         Mew  Psychic  405.0  100     100      100      100    100.0
#
#      Speed  Stage  Legendary
# ...

# %% [markdown]
# #### Flagging apakah pokemon ini memiliki Type 1 sama dengan Fire

# %%
is_fire_pokemon = []
for value in data_pokemon['Type 1']:
    if value == 'Fire':
        is_fire_pokemon.append(True)
    else:
        is_fire_pokemon.append(False)

# %%
# Check dulu length ada berapa
len(is_fire_pokemon)
# Out:
# 151

# %%
if len(is_fire_pokemon) == len(data_pokemon):
    data_pokemon['is_fire_pokemon'] = is_fire_pokemon
# Out:
# C:\Users\bdrex\AppData\Local\Temp\ipykernel_26512\789459738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pokemon['is_fire_pokemon'] = is_fire_pokemon

# %%
data_pokemon.tail()
# Out:
#       No       Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 146  147    Dratini   Dragon  300.0   41      64       45       50     50.0
# 147  148  Dragonair   Dragon  420.0   61      84       65       70     70.0
# 148  149  Dragonite   Dragon  405.0   91     134       95      100    100.0
# 149  150     Mewtwo  Psychic  680.0  106     110       90      154     90.0
# 150  151        Mew  Psychic  405.0  100     100      100      100    100.0
#
#      Speed  Stage  Legendary  is_fire_pokemon
# 146     50      1      False            False
# 147     70      2      False            False
# 148     80      3      False            False
# 149    130      1       True            False
# 150    100      1      False            False

# %% [markdown]
# #### Data Duplicate

# %% [markdown]
# #### Check Apakah Ada Data Duplicate

# %%
data_pokemon.loc[data_pokemon.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [No, Name, Type 1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Stage, Legendary]
# Index: []

# %%
data_pokemon = pd.concat((data_pokemon, data_pokemon), axis=0)

# %%
data_pokemon.loc[data_pokemon.duplicated()==True]
# Out:
#       No        Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  318.0   45      49       49       65     65.0
# 1      2     Ivysaur    Grass  405.0   60      62       63       80     80.0
# 2      3    Venusaur    Grass  525.0   80      82       83      100    100.0
# 3      4  Charmander     Fire  309.0   39      52       43       60     50.0
# 4      5  Charmeleon     Fire  405.0   58      64       58       80     65.0
# ..   ...         ...      ...    ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon  300.0   41      64       45       50     50.0
# 147  148   Dragonair   Dragon  420.0   61      84       65       70     70.0
# 148  149   Dragonite   Dragon  405.0   91     134       95      100    100.0
# 149  150      Mewtwo  Psychic  680.0  106     110       90      154     90.0
# 150  151         Mew  Psychic  405.0  100     100      100      100    100.0
#
#      Speed  Stage  Legendary
# ...

# %% [markdown]
# #### Ngeliat Duplicated, based on data duplikasi di column itu saja.

# %%
data_pokemon[data_pokemon.duplicated(subset=['Name'])]
# Out:
#     No        Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 31  32  Nidoran���  Poison  273.0  46      57       40       40     40.0
#
#     Speed  Stage  Legendary  is_fire_pokemon
# 31     50      1      False            False

# %%
# ngeliat semua data yang dibilang duplicate
data_pokemon[data_pokemon.duplicated(subset=['Name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [No, Name, Type 1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Stage, Legendary, is_fire_pokemon]
# Index: []

# %%
index_yang_mau_di_drop = data_pokemon[data_pokemon.duplicated(subset=['Name'])].index

# %%
data_pokemon = data_pokemon.drop(index=index_yang_mau_di_drop,axis=0) # ngedrop index, berdasarkan index yang mau di drop.

# %%
data_pokemon
# Out:
#       No        Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  318.0   45      49       49       65     65.0
# 1      2     Ivysaur    Grass  405.0   60      62       63       80     80.0
# 2      3    Venusaur    Grass  525.0   80      82       83      100    100.0
# 3      4  Charmander     Fire  309.0   39      52       43       60     50.0
# 4      5  Charmeleon     Fire  405.0   58      64       58       80     65.0
# ..   ...         ...      ...    ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon  300.0   41      64       45       50     50.0
# 147  148   Dragonair   Dragon  420.0   61      84       65       70     70.0
# 148  149   Dragonite   Dragon  405.0   91     134       95      100    100.0
# 149  150      Mewtwo  Psychic  680.0  106     110       90      154     90.0
# 150  151         Mew  Psychic  405.0  100     100      100      100    100.0
#
# ...

# %%
data_pokemon[data_pokemon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [No, Name, Type 1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Stage, Legendary, is_fire_pokemon]
# Index: []

# %% [markdown]
# #### Remove Duplicate

# %%
data_pokemon = data_pokemon.drop_duplicates()

# %%
data_pokemon.loc[data_pokemon.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [No, Name, Type 1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Stage, Legendary]
# Index: []
